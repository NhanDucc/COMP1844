# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Moscow temperatures (Cold Climate)
moscow_temps = np.array([-10, -9, -5, 1, 7, 14, 17, 16, 11, 3, -3, -8])

# Cairo temperatures (Hot Climate)
cairo_temps = np.array([15, 16, 18, 22, 26, 30, 33, 35, 31, 26, 20, 16])

# %%
# Define month names
months = ["January", "February", "March", "April", "May", "June", 
          "July", "August", "September", "October", "November", "December"]

# Moscow temperatures (Cold Climate)
moscow_temps = np.array([-10, -9, -5, 1, 7, 14, 17, 16, 11, 3, -3, -8])

# Cairo temperatures (Hot Climate)
cairo_temps = np.array([15, 16, 18, 22, 26, 30, 33, 35, 31, 26, 20, 16])

# Create a DataFrame for better visualization
df = pd.DataFrame({
    "Month": months,
    "Moscow (°C)": moscow_temps,
    "Cairo (°C)": cairo_temps
})

# Print the table
print(df)
# Out:
#         Month  Moscow (°C)  Cairo (°C)
# 0     January          -10          15
# 1    February           -9          16
# 2       March           -5          18
# 3       April            1          22
# 4         May            7          26
# 5        June           14          30
# 6        July           17          33
# 7      August           16          35
# 8   September           11          31
# 9     October            3          26
# 10   November           -3          20
# 11   December           -8          16

# %%
# Define month names
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# Moscow temperatures (Cold Climate)
moscow_temps = np.array([-10, -9, -5, 1, 7, 14, 17, 16, 11, 3, -3, -8])

# Cairo temperatures (Hot Climate)
cairo_temps = np.array([15, 16, 18, 22, 26, 30, 33, 35, 31, 26, 20, 16])

# 2.1 Line Chart
plt.figure(figsize=(10,5))
plt.plot(months, moscow_temps, marker='o', label="Moscow (°C)", linestyle='-')
plt.plot(months, cairo_temps, marker='s', label="Cairo (°C)", linestyle='--')
plt.title("Average Monthly Temperatures: Moscow vs Cairo")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.grid(True)
plt.show()

# 2.2 Bar Chart
bar_width = 0.4
x = np.arange(len(months))

plt.figure(figsize=(10,5))
plt.bar(x - bar_width/2, moscow_temps, width=bar_width, label="Moscow (°C)", color='blue')
plt.bar(x + bar_width/2, cairo_temps, width=bar_width, label="Cairo (°C)", color='orange')
plt.xticks(ticks=x, labels=months)
plt.title("Average Monthly Temperatures: Moscow vs Cairo")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.show()

# 2.3 Box Plot
data = pd.DataFrame({
    "City": ["Moscow"]*12 + ["Cairo"]*12,
    "Temperature (°C)": np.concatenate([moscow_temps, cairo_temps]),
    "Month": months * 2
})

plt.figure(figsize=(8,6))
sns.boxplot(x="City", y="Temperature (°C)", data=data, palette=["blue", "orange"])
plt.title("Temperature Distribution: Moscow vs Cairo")
plt.show()
# Out:
# C:\Temp\ipykernel_9736\1697476931.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="City", y="Temperature (°C)", data=data, palette=["blue", "orange"])
