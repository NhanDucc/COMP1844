# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Task 1
uniform_data = np.random.uniform(0, 100, 50)
print(f"Uniform distribution data: {uniform_data}")
# Out:
# Uniform distribution data: [ 0.31458342 57.62843814 12.77866253 22.10423181 11.53844296 71.95397094
#  89.96655388 17.01567758 15.97089817  0.17241612 24.23258378 55.28877617
#  72.54609681 64.63057221 70.23564694  1.0784706  53.65450264 74.51113355
#  39.10372064 25.41579389 41.0315185  65.42592099 24.01046892 46.72669337
#   3.16692397  1.97572648 94.05967234  8.1647811  94.39976288 85.59443543
#  68.56386437 45.5559915  38.49337251  1.82471837  6.72312166 58.69082162
#   4.62163394 23.78682623 33.5245924  70.5661987  94.05147499 20.95762026
#  13.968462   93.8013993  33.42270284 35.01757193 21.10162572 90.14059943
#  55.51521483 38.38897906]

# %%
# Task 2
# Find the minimum, maximum, and range of the data
min_val = np.min(uniform_data)
max_val = np.max(uniform_data)
data_range = max_val - min_val

print(f"Minimum Value: {round(min_val, 2)}")
print(f"Maximum Value: {round(max_val, 2)}")
print(f"Range: {round(data_range, 2)}")
# Out:
# Minimum Value: 0.17
# Maximum Value: 94.4
# Range: 94.23

# %%
# Task 3
# Mean = 17, Std = 0.2, Size = 1000. Count Normal
normal_data = np.random.normal(17, 0.2, 1000)
print("First 10 values from Normal Distribution:\n", normal_data[:10])
# Out:
# First 10 values from Normal Distribution:
#  [16.72008129 16.71898889 16.90849522 16.99925892 17.02929836 16.92439415
#  16.6359598  17.16259072 16.66845823 16.48158046]

# %%
# Task 4
# Find the minimum, maximum, and range of the data
min_normal = np.min(normal_data)
max_normal = np.max(normal_data)
range_normal = max_normal - min_normal

print(f"Minimum Value: {round(min_normal, 2)}")
print(f"Maximum Value: {round(max_normal, 2)}")
print(f"Range: {round(range_normal, 2)}")
# Out:
# Minimum Value: 16.44
# Maximum Value: 17.59
# Range: 1.15

# %%
# Task 5
# Create a histogram of the data
# bin = 10
plt.figure(figsize=(10, 6))

# Create histogram
A, X, C = plt.hist(normal_data, bins=10, density=True)

# Generate points for the PDF curve
x = np.linspace(min_normal - 0.5, max_normal + 0.5, 100)
pdf = (1 / (0.2 * np.sqrt(2 * np.pi))) * np.exp(-(x - 17)**2 / (2 * 0.2**2))

# Plot PDF
plt.plot(x, pdf, 'r-', lw=2, label='PDF')

plt.title('Normal Distribution')
plt.xlabel('Values')
plt.ylabel('Density')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
